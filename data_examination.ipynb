# %%
import synapseclient
import synapseutils

syn = synapseclient.Synapse()
syn.login('DavidMcDonald93','C423612k')
files = synapseutils.syncFromSynapse(syn, 'syn8564279')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-979eb9f3f9f3> in <module>()
#       3
#       4 syn = synapseclient.Synapse()
# ----> 5 syn.login('DavidMcDonald93','C423612k')
#       6 files = synapseutils.syncFromSynapse(syn, 'syn8564279')
#
# /home/david/miniconda2/lib/python2.7/site-packages/synapseclient/client.pyc in login(self, email, password, apiKey, sessionToken, rememberMe, silent, forced)
#     339
#     340         try:
# --> 341             self.username, self.apiKey = self._get_login_credentials(email, password, apiKey, sessionToken)
#     342         except SynapseAuthenticationError:
#     343             pass
#
# /home/david/miniconda2/lib/python2.7/site-packages/synapseclient/client.pyc in _get_login_credentials(self, username, password, apikey, sessiontoken)
#     403         if username is not None and password is not None:
# ...

# %%
import numpy as np
import pandas as pd

dfs = [pd.read_csv("./dream_proteogenomics_challenge_dataset/sub_challenge_1/data_obs_{}.txt".format(i), 
                header=0, index_col=0, sep="\t") for i in range(1, 11)]

ground_truth_table = pd.read_csv("./dream_proteogenomics_challenge_dataset/sub_challenge_1/data_true.txt", 
                header=0, index_col=0, sep="\t")

# %%
datas = [df.values for df in dfs]
ground_truth = ground_truth_table.values

# %%
zeros = np.where(ground_truth == 0)

# %%
[np.isnan(data[zeros]).all() for data in datas]
# Out:
# [True, True, True, True, True, True, True, True, True, True]

# %%
import pandas as pd

# %%
D = pd.read_csv("./dream_proteogenomics_challenge_dataset/sub_challenge_1/data_obs_4.txt", 
                header=0, index_col=0, sep="\t")

# %%
D
# Out:
#                Sample_1   Sample_2   Sample_3   Sample_4   Sample_5  \
# Gene_ID
# Protein_1     30.391022  29.103878  30.070138  29.258080  29.371801
# Protein_2     30.386360  29.093534  30.058996  29.249482  29.353317
# Protein_3           NaN  29.091844  30.059338  29.249809        NaN
# Protein_4     30.387267  29.101236  30.059926  29.248510        NaN
# Protein_5     30.386282  29.097235  30.061090  29.250285  29.354130
# Protein_6     30.386118  29.091964  30.058786        NaN  29.353798
# Protein_7     30.386526  29.093700  30.059162  29.249645        NaN
# Protein_8     30.386506  29.093680  30.059142  29.249629        NaN
# Protein_9           NaN  26.720081  26.766650  26.554346  26.461061
# Protein_10          NaN  30.548320        NaN        NaN  30.181093
# Protein_11    22.630895  23.075465        NaN  22.483771        NaN
# Protein_12    28.410374  27.323855  28.351854  27.626105  27.651784
# Protein_13    26.029391  26.187927  25.940386  25.719947  25.688932
# ...

# %%
D2 = pd.read_csv("./dream_proteogenomics_challenge_dataset/sub_challenge_1/data_obs_5.txt", 
                header=0, index_col=0, sep="\t")

# %%
D2
# Out:
#                Sample_1   Sample_2   Sample_3   Sample_4   Sample_5  \
# Gene_ID
# Protein_1     30.391022  29.103878  30.070138  29.258080        NaN
# Protein_2     30.386360  29.093534  30.058996  29.249482  29.353317
# Protein_3           NaN  29.091844        NaN  29.249809        NaN
# Protein_4     30.387267  29.101236  30.059926        NaN        NaN
# Protein_5     30.386282  29.097235  30.061090  29.250285  29.354130
# Protein_6     30.386118  29.091964  30.058786        NaN  29.353798
# Protein_7     30.386526  29.093700  30.059162        NaN        NaN
# Protein_8     30.386506  29.093680  30.059142  29.249629  29.354490
# Protein_9     28.182457  26.720081  26.766650  26.554346  26.461061
# Protein_10    30.243036  30.548320        NaN  29.781248  30.181093
# Protein_11    22.630895  23.075465        NaN        NaN        NaN
# Protein_12    28.410374  27.323855  28.351854  27.626105  27.651784
# Protein_13    26.029391  26.187927  25.940386  25.719947  25.688932
# ...

# %%
D_prime = pd.read_csv("./dream_proteogenomics_challenge_dataset/sub_challenge_1/data_true.txt", 
                header=0, index_col=0, sep="\t")

# %%
D_prime
# Out:
#                Sample_1   Sample_2   Sample_3   Sample_4   Sample_5  \
# Gene_ID
# Protein_1     30.391022  29.103878  30.070138  29.258080  29.371801
# Protein_2     30.386360  29.093534  30.058996  29.249482  29.353317
# Protein_3      0.000000  29.091844  30.059338  29.249809   0.000000
# Protein_4     30.387267  29.101236  30.059926  29.248510   0.000000
# Protein_5     30.386282  29.097235  30.061090  29.250285  29.354130
# Protein_6     30.386118  29.091964  30.058786   0.000000  29.353798
# Protein_7     30.386526  29.093700  30.059162  29.249645   0.000000
# Protein_8     30.386506  29.093680  30.059142  29.249629  29.354490
# Protein_9     28.182457  26.720081  26.766650  26.554346  26.461061
# Protein_10    30.243036  30.548320   0.000000  29.781248  30.181093
# Protein_11    22.630895  23.075465   0.000000  22.483771   0.000000
# Protein_12    28.410374  27.323855  28.351854  27.626105  27.651784
# Protein_13    26.029391  26.187927  25.940386  25.719947  25.688932
# ...

# %%
F = pd.read_csv("./dream_proteogenomics_challenge_dataset/sub_challenge_2_3/breast_cancer_dataset/retrospective_breast_proteome_filtered.txt", 
                header=0, index_col=0, sep="\t")

# %%
F
# Out:
#           TCGA-A2-A0CM  TCGA-A2-A0D0  TCGA-A2-A0D1  TCGA-A2-A0D2  \
# Gene_ID
# A1BG         -0.276307      0.761778      1.402908      0.012759
# A2M          -0.118270      0.748086      1.276917     -0.071747
# A2ML1         1.603553     -2.222585     -0.045539     -0.335392
# AAAS          0.101726      1.375898      1.035998      0.380816
# AACS         -0.810788     -0.195034     -0.641933     -0.541776
# AADAT         0.317376           NaN      2.429252      0.745095
# AAED1              NaN     -2.723451           NaN      0.371865
# AAGAB        -0.266172     -0.039713      0.889269     -0.208586
# AAK1         -0.000203      0.016042      0.672384      0.016923
# AAMDC        -0.191256     -2.352836     -2.413103     -0.676513
# AAMP         -0.351906     -0.550726     -0.290192     -0.170658
# AAR2          0.257077      1.693848      0.399796      0.236581
# AARD               NaN           NaN           NaN           NaN
# ...

# %%
G = pd.read_csv("./dream_proteogenomics_challenge_dataset/sub_challenge_2_3/breast_cancer_dataset/retrospective_breast_CNA_median_sort_common_gene_16884.txt", 
                header=0, index_col=0, sep="\t")

# %%
G
# Out:
#           TCGA-A2-A0CM  TCGA-A2-A0D2  TCGA-A2-A0EQ  TCGA-A2-A0EV  \
# Gene_ID
# A1BG             0.017         0.823         0.137         0.241
# A1CF             0.325         0.577         0.149        -0.340
# A2M             -0.014        -0.030         0.020        -0.368
# A2ML1           -0.014        -0.030         0.020        -0.368
# A4GALT          -0.304        -0.076        -0.028        -0.148
# A4GNT            0.549        -0.031        -0.161        -0.005
# AAAS            -0.310        -0.028         0.002         0.324
# AACS             0.325         0.596        -0.007         0.328
# AADAC            0.554        -0.031        -0.161        -0.005
# AADACL3          0.122        -0.085        -0.038        -0.026
# AADACL4          0.122        -0.085        -0.038        -0.026
# AADAT           -0.022        -0.036        -0.161         0.005
# AAGAB           -0.119         0.568        -0.337         0.308
# ...

# %%
H = pd.read_csv("./dream_proteogenomics_challenge_dataset/sub_challenge_2_3/breast_cancer_dataset/retrospective_breast_rna_seq_sort_common_gene_15115.txt", 
                header=0, index_col=0, sep="\t")

# %%
H
# Out:
#            TCGA-A2-A0CM  TCGA-A2-A0D2  TCGA-A2-A0EQ  TCGA-A2-A0EV  \
# Gene_ID
# A1BG          -1.381720     -2.362704     -2.235947     -0.949779
# A2M           -0.614730      1.647478     -0.130629     -0.320752
# A2ML1          7.555057     -2.772401      1.437432     -2.262480
# A4GALT        -1.067624     -1.136854     -1.143549     -0.727104
# AAAS          -0.387839      0.140225      0.194646      0.394949
# AACS          -0.744971      0.048323     -0.010526      0.029900
# AADAT          2.344825      1.895878      1.500529     -1.203849
# AAGAB         -1.042709     -0.001386     -0.275340      0.362381
# AAK1          -0.279343     -0.701225     -0.249741      0.250908
# AAMP          -0.185644      0.056869      0.233649     -0.094671
# AARS           0.838359      1.327981      0.978207      0.098340
# AARS2          0.049315      0.296051      0.099098      0.056755
# AARSD1         0.148661      0.106424     -0.018859      1.281394
# ...

# %%
I = pd.read_csv("./dream_proteogenomics_challenge_dataset/sub_challenge_2_3/breast_cancer_dataset/retrospective_breast_phospho_filtered.txt", 
                header=0, index_col=0, sep="\t")

# %%
I
# Out:
#                            TCGA-A2-A0CM  TCGA-A2-A0D0  TCGA-A2-A0D1  \
# Gene_ID
# NP_000007.1:t51                     NaN           NaN           NaN
# NP_000009.1:s522                    NaN           NaN           NaN
# NP_000012.1:s366s367                NaN           NaN           NaN
# NP_000012.1:s367               0.726089     -0.642723     -0.660573
# NP_000012.1:s43                0.107737     -4.540683     -5.787818
# NP_000022.3:s214              -0.166571     -6.001212     -4.857717
# NP_000022.3:s215              -0.503071           NaN     -5.061434
# NP_000025.1:s132              -0.389552     -0.731055     -0.412302
# NP_000025.1:s17                     NaN           NaN           NaN
# NP_000025.1:s218                    NaN           NaN           NaN
# NP_000025.1:s272              -0.676362           NaN     -0.817395
# NP_000025.1:s276                    NaN           NaN           NaN
# NP_000025.1:s346                    NaN           NaN           NaN
# ...
